# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-machine-learning/resources/bANLa) course resource._
#
# ---

# %% [markdown]
# ## Assignment 4 - Understanding and Predicting Property Maintenance Fines
#
# This assignment is based on a data challenge from the Michigan Data Science Team ([MDST](http://midas.umich.edu/mdst/)).
#
# The Michigan Data Science Team ([MDST](http://midas.umich.edu/mdst/)) and the Michigan Student Symposium for Interdisciplinary Statistical Sciences ([MSSISS](https://sites.lsa.umich.edu/mssiss/)) have partnered with the City of Detroit to help solve one of the most pressing problems facing Detroit - blight. [Blight violations](http://www.detroitmi.gov/How-Do-I/Report/Blight-Complaint-FAQs) are issued by the city to individuals who allow their properties to remain in a deteriorated condition. Every year, the city of Detroit issues millions of dollars in fines to residents and every year, many of these fines remain unpaid. Enforcing unpaid blight fines is a costly and tedious process, so the city wants to know: how can we increase blight ticket compliance?
#
# The first step in answering this question is understanding when and why a resident might fail to comply with a blight ticket. This is where predictive modeling comes in. For this assignment, your task is to predict whether a given blight ticket will be paid on time.
#
# All data for this assignment has been provided to us through the [Detroit Open Data Portal](https://data.detroitmi.gov/). **Only the data already included in your Coursera directory can be used for training the model for this assignment.** Nonetheless, we encourage you to look into data from other Detroit datasets to help inform feature creation and model selection. We recommend taking a look at the following related datasets:
#
# * [Building Permits](https://data.detroitmi.gov/Property-Parcels/Building-Permits/xw2a-a7tf)
# * [Trades Permits](https://data.detroitmi.gov/Property-Parcels/Trades-Permits/635b-dsgv)
# * [Improve Detroit: Submitted Issues](https://data.detroitmi.gov/Government/Improve-Detroit-Submitted-Issues/fwz3-w3yn)
# * [DPD: Citizen Complaints](https://data.detroitmi.gov/Public-Safety/DPD-Citizen-Complaints-2016/kahe-efs3)
# * [Parcel Map](https://data.detroitmi.gov/Property-Parcels/Parcel-Map/fxkw-udwf)
#
# ___
#
# We provide you with two data files for use in training and validating your models: train.csv and test.csv. Each row in these two files corresponds to a single blight ticket, and includes information about when, why, and to whom each ticket was issued. The target variable is compliance, which is True if the ticket was paid early, on time, or within one month of the hearing data, False if the ticket was paid after the hearing date or not at all, and Null if the violator was found not responsible. Compliance, as well as a handful of other variables that will not be available at test-time, are only included in train.csv.
#
# Note: All tickets where the violators were found not responsible are not considered during evaluation. They are included in the training set as an additional source of data for visualization, and to enable unsupervised and semi-supervised approaches. However, they are not included in the test set.
#
# <br>
#
# **File descriptions** (Use only this data for training your model!)
#
#     train.csv - the training set (all tickets issued 2004-2011)
#     test.csv - the test set (all tickets issued 2012-2016)
#     addresses.csv & latlons.csv - mapping from ticket id to addresses, and from addresses to lat/lon coordinates.
#      Note: misspelled addresses may be incorrectly geolocated.
#
# <br>
#
# **Data fields**
#
# train.csv & test.csv
#
#     ticket_id - unique identifier for tickets
#     agency_name - Agency that issued the ticket
#     inspector_name - Name of inspector that issued the ticket
#     violator_name - Name of the person/organization that the ticket was issued to
#     violation_street_number, violation_street_name, violation_zip_code - Address where the violation occurred
#     mailing_address_str_number, mailing_address_str_name, city, state, zip_code, non_us_str_code, country - Mailing address of the violator
#     ticket_issued_date - Date and time the ticket was issued
#     hearing_date - Date and time the violator's hearing was scheduled
#     violation_code, violation_description - Type of violation
#     disposition - Judgment and judgement type
#     fine_amount - Violation fine amount, excluding fees
#     admin_fee - $20 fee assigned to responsible judgments
# state_fee - $10 fee assigned to responsible judgments
#     late_fee - 10% fee assigned to responsible judgments
#     discount_amount - discount applied, if any
#     clean_up_cost - DPW clean-up or graffiti removal cost
#     judgment_amount - Sum of all fines and fees
#     grafitti_status - Flag for graffiti violations
#
# train.csv only
#
#     payment_amount - Amount paid, if any
#     payment_date - Date payment was made, if it was received
#     payment_status - Current payment status as of Feb 1 2017
#     balance_due - Fines and fees still owed
#     collection_status - Flag for payments in collections
#     compliance [target variable for prediction]
#      Null = Not responsible
#      0 = Responsible, non-compliant
#      1 = Responsible, compliant
#     compliance_detail - More information on why each ticket was marked compliant or non-compliant
#
#
# ___
#
# ## Evaluation
#
# Your predictions will be given as the probability that the corresponding blight ticket will be paid on time.
#
# The evaluation metric for this assignment is the Area Under the ROC Curve (AUC).
#
# Your grade will be based on the AUC score computed for your classifier. A model which with an AUROC of 0.7 passes this assignment, over 0.75 will recieve full points.
# ___
#
# For this assignment, create a function that trains a model to predict blight ticket compliance in Detroit using `train.csv`. Using this model, return a series of length 61001 with the data being the probability that each corresponding ticket from `test.csv` will be paid, and the index being the ticket_id.
#
# Example:
#
#     ticket_id
#        284932    0.531842
#        285362    0.401958
#        285361    0.105928
#        285338    0.018572
#                  ...
#        376499    0.208567
#        376500    0.818759
#        369851    0.018528
#        Name: compliance, dtype: float32

# %%
import pandas as pd
import numpy as np

def blight_model():
    
    import matplotlib.pyplot as plt
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import roc_auc_score
    from sklearn.model_selection import train_test_split

    train = pd.read_csv('train.csv', encoding='latin1')
    test  = pd.read_csv('test.csv').set_index('ticket_id')
    df1 = train[pd.notnull(train.compliance)].set_index('ticket_id')
    features = ['fine_amount', 'admin_fee', 'state_fee', 'late_fee', 'discount_amount', 'discount_amount', 'clean_up_cost', 'judgment_amount']
    X_data = df1[features]
    y_data = df1['compliance']
    
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data)

    clf = LogisticRegression(C=0.0001).fit(X_train, y_train)
    y_proba_clf = clf.predict_proba(X_test)
    test['compliance']= clf.predict_proba(test[features])[:,1]
#    print(roc_auc_score(y_test,clf.predict_proba(X_test)[:,1],))
    
    return test['compliance']

blight_model()
# Out:
# D:\Users\iamfish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2909: DtypeWarning: Columns (11,12,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# ticket_id
# 284932    5.904444e-02
# 285362    5.674160e-03
# 285361    7.806640e-02
# 285338    5.904444e-02
# 285346    7.806640e-02
# 285345    5.904444e-02
# 285347    8.955607e-02
# 285342    1.902597e-01
# 285530    5.674160e-03
# 284989    2.489977e-02
# 285344    8.955607e-02
# 285343    5.674160e-03
# 285340    5.674160e-03
# 285341    8.955607e-02
# 285349    7.806640e-02
# 285348    5.904444e-02
# 284991    2.489977e-02
# 285532    2.489977e-02
# 285406    2.489977e-02
# 285001    2.489977e-02
# 285006    5.674160e-03
# 285405    5.674160e-03
# 285337    2.489977e-02
# 285496    8.955607e-02
# 285497    5.904444e-02
# 285378    5.674160e-03
# 285589    2.489977e-02
# 285585    5.904444e-02
# 285501    7.806640e-02
# 285581    5.674160e-03
#               ...
# 376367    1.192747e-02
# 376366    5.124894e-02
# 376362    5.124894e-02
# 376363    5.904444e-02
# 376365    1.192747e-02
# 376364    5.124894e-02
# 376228    5.124894e-02
# 376265    5.124894e-02
# 376286    2.195828e-01
# 376320    5.124894e-02
# 376314    5.124894e-02
# 376327    2.195828e-01
# 376385    2.195828e-01
# 376435    6.304493e-01
# 376370    2.195828e-01
# 376434    8.955607e-02
# 376459    7.806640e-02
# 376478    3.549667e-08
# 376473    5.124894e-02
# 376484    4.443405e-02
# 376482    2.489977e-02
# 376480    2.489977e-02
# 376479    2.489977e-02
# 376481    2.489977e-02
# 376483    5.124894e-02
# 376496    5.674160e-03
# 376497    5.674160e-03
# 376499    7.806640e-02
# 376500    7.806640e-02
# 369851    1.203630e-01
# Name: compliance, Length: 61001, dtype: float64

# %%
train = pd.read_csv('train.csv', encoding='latin1')
test  = pd.read_csv('test.csv')
addr  = pd.read_csv('addresses.csv')
latlon= pd.read_csv('latlons.csv')
latlon.head()
# Out:
# D:\Users\iamfish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11,12,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                   address        lat        lon
# 0  4300 rosa parks blvd, Detroit MI 48208  42.346169 -83.079962
# 1                14512 sussex, Detroit MI  42.394657 -83.194265
# 2                3456 garland, Detroit MI  42.373779 -82.986228
# 3                5787 wayburn, Detroit MI  42.403342 -82.957805
# 4              5766 haverhill, Detroit MI  42.407255 -82.946295

# %%
df1 = train.merge(addr, left_on='ticket_id', right_on='ticket_id', how='left')
df1 = df1.merge(latlon, left_on='address', right_on='address', how='left')
df1b = df1[['ticket_id', 'judgment_amount', 'lat', 'lon', 'compliance']].dropna()
X_data = df1b[['judgment_amount']]
y_data = df1b['compliance']

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data)


'''
clf = SVC(kernel='rbf')
grid_values = {'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100]}
#grid_values = {'gamma': [0.001,1]}

# default metric to optimize over grid parameters: accuracy
grid_clf = GridSearchCV(clf, param_grid = grid_values)
grid_clf.fit(X_train, y_train)
y_decision_scoresc = grid_clf.decision_function(X_test) 

print('Test set AUC: ', roc_auc_score(y_test, y_decision_scoresc))
print('Grid best parameter (max. AUC): ', grid_clf.best_params_)
print('Grid best score (AUC): ', grid_clf.best_score_)
'''

clf = LogisticRegression().fit(X_train, y_train)
print(clf.score(X_test, y_test))
y_proba_clf = clf.predict_proba(X_test)
print(list(zip(y_test[0:20], y_proba_clf[0:20,1])))



y_score_clf = clf.decision_function(X_test)
fpr_clf, tpr_clf, _ = roc_curve(y_test, y_score_clf)
roc_auc_clf = auc(fpr_clf, tpr_clf)

plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr_clf, tpr_clf, lw=3, label='LogRegr ROC curve (area = {:0.2f})'.format(roc_auc_clf))
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc='lower right', fontsize=13)
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
#plt.axes().set_aspect('equal')
plt.show()
# Out:
# 0.9282211658744058
# [(0.0, 0.08635321930791368), (0.0, 0.07361626362165), (0.0, 0.08635321930791368), (0.0, 0.07361626362165), (0.0, 0.07361626362165), (0.0, 0.07361626362165), (0.0, 0.08299335978814829), (0.0, 0.07361626362165), (0.0, 0.07361626362165), (1.0, 0.07361626362165), (0.0, 0.07361626362165), (1.0, 0.08666469417883704), (0.0, 0.07497158829928331), (0.0, 0.07361626362165), (0.0, 1.692210624875991e-05), (0.0, 0.08635321930791368), (0.0, 0.07361626362165), (0.0, 0.08635321930791368), (0.0, 0.08666469417883704), (0.0, 0.07071362180133738)]

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

train = pd.read_csv('train.csv', encoding='latin1')
test  = pd.read_csv('test.csv').set_index('ticket_id')

df1 = train[pd.notnull(train.compliance)].set_index('ticket_id')
features = ['fine_amount', 'admin_fee', 'state_fee', 'late_fee', 'discount_amount', 'discount_amount', 'clean_up_cost', 'judgment_amount']
X_data = df1[features]
y_data = df1['compliance']

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data)

clf = LogisticRegression(C=0.0001).fit(X_train, y_train)
y_proba_clf = clf.predict_proba(X_test)
test['compliance']= clf.predict_proba(test[features])[:,1]
print(roc_auc_score(y_test,clf.predict_proba(X_test)[:,1],))
# Out:
# D:\Users\iamfish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11,12,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0.757415008922267

# %%
test
# Out:
#                                               agency_name      inspector_name  \
# ticket_id
# 284932                         Department of Public Works  Granberry, Aisha B
# 285362                         Department of Public Works      Lusk, Gertrina
# 285361                         Department of Public Works      Lusk, Gertrina
# 285338                         Department of Public Works   Talbert, Reginald
# 285346                         Department of Public Works   Talbert, Reginald
# 285345                         Department of Public Works   Talbert, Reginald
# 285347                         Department of Public Works   Talbert, Reginald
# 285342                         Department of Public Works   Talbert, Reginald
# 285530                         Department of Public Works     Buchanan, Daryl
# 284989                         Department of Public Works     Buchanan, Daryl
# 285344                         Department of Public Works   Talbert, Reginald
# 285343                         Department of Public Works   Talbert, Reginald
# 285340                         Department of Public Works   Talbert, Reginald
# 285341                         Department of Public Works   Talbert, Reginald
# 285349                         Department of Public Works   Talbert, Reginald
# 285348                         Department of Public Works   Talbert, Reginald
# 284991                         Department of Public Works     Buchanan, Daryl
# 285532                         Department of Public Works     Buchanan, Daryl
# 285406                         Department of Public Works     Frazier, Willie
# 285001     Buildings, Safety Engineering & Env Department    Addison, Michael
# 285006     Buildings, Safety Engineering & Env Department    Addison, Michael
# 285405                         Department of Public Works       Traylor, Alva
# 285337                         Department of Public Works       Bell, Maydell
# 285496                         Department of Public Works     Mathis, Marlena
# 285497                         Department of Public Works     Mathis, Marlena
# 285378                         Department of Public Works      Lusk, Gertrina
# 285589                         Department of Public Works      Lusk, Gertrina
# 285585                         Department of Public Works      Lusk, Gertrina
# 285501                         Department of Public Works     Mathis, Marlena
# 285581                         Department of Public Works      Lusk, Gertrina
# ...                                                   ...                 ...
# 376367     Buildings, Safety Engineering & Env Department        Bou, Jeffrey
# 376366     Buildings, Safety Engineering & Env Department        Bou, Jeffrey
# 376362     Buildings, Safety Engineering & Env Department        Bou, Jeffrey
# 376363     Buildings, Safety Engineering & Env Department        Bou, Jeffrey
# 376365     Buildings, Safety Engineering & Env Department        Bou, Jeffrey
# 376364     Buildings, Safety Engineering & Env Department        Bou, Jeffrey
# 376228     Buildings, Safety Engineering & Env Department     Sparks, William
# 376265     Buildings, Safety Engineering & Env Department     DeRamer, Andrew
# 376286     Buildings, Safety Engineering & Env Department     Brinkley, Kevin
# 376320     Buildings, Safety Engineering & Env Department     CROTTEAU, LOUIS
# 376314     Buildings, Safety Engineering & Env Department       Chacko, Moncy
# 376327     Buildings, Safety Engineering & Env Department          Keys, Edna
# 376385     Buildings, Safety Engineering & Env Department        Bush, Wesley
# 376435     Buildings, Safety Engineering & Env Department     Sparks, William
# 376370     Buildings, Safety Engineering & Env Department     Sparks, William
# 376434                          Detroit Police Department    Nichols, Douglas
# 376459                          Detroit Police Department    Nichols, Douglas
# 376478                          Detroit Police Department    Nichols, Douglas
# 376473     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376484     Buildings, Safety Engineering & Env Department     Sparks, William
# 376482     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376480     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376479     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376481     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376483     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376496     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376497     Buildings, Safety Engineering & Env Department      Pierson, Kevin
# 376499                          Detroit Police Department     BOWLES, TIFFANI
# 376500                          Detroit Police Department     BOWLES, TIFFANI
# 369851                         Department of Public Works  Johnson, Valentina
#
#                                              violator_name  \
# ticket_id
# 284932                                    FLUELLEN, JOHN A
# 285362                                     WHIGHAM, THELMA
# 285361                                     WHIGHAM, THELMA
# 285338                                  HARABEDIEN, POPKIN
# 285346                                    CORBELL, STANLEY
# 285345                                    CORBELL, STANLEY
# 285347                                    CORBELL, STANLEY
# 285342                          NICKOLA CORPORATION, W & H
# 285530                   INTERSTATE INVESTMENT GROUP LL, .
# 284989                                      YAMAN, BATURAY
# 285344                                       RENT LLC, KEY
# 285343                                       RENT LLC, KEY
# 285340                         KAY PROPERTIES LLC, KAY BEE
# 285341                         KAY PROPERTIES LLC, KAY BEE
# 285349                            PORTFOLIO VI LP, HARBOUR
# 285348                            PORTFOLIO VI LP, HARBOUR
# 284991                                    SKOUBY, CLIFFORD
# 285532                                      PITTS, RENNELL
# 285406                     ENTERPRISE, LLC, SHANNON GLOBAL
# 285001                                     Cordoba, Victor
# 285006                                     Cordoba, Victor
# 285405                                       GROUP, NESSKO
# 285337                        LAND HOLDING, LLC, PARAMOUNT
# 285496                RODERICK GILLISON, ONE ACCORD REALTY
# 285497                RODERICK GILLISON, ONE ACCORD REALTY
# 285378                         INVESTMENTS OPP, STONECREST
# 285589                  SERVICES, DESERT MANAGEMENT  GROUP
# 285585                                       LLC, COURTESY
# 285501                       EARL L. HARRIS, MONIQUE JONES
# 285581                              PITTS II, WALTER ALLEN
# ...                                                    ...
# 376367                             Cromer Enterprises Inc.
# 376366                             Cromer Enterprises Inc.
# 376362                                        Makadm Corp.
# 376363                                        Makadm Corp.
# 376365                       Universal Tire Recycling Inc.
# 376364                       Universal Tire Recycling Inc.
# 376228                                     Supino Pizzeria
# 376265                              R & R MANAGEMENT GROUP
# 376286                                 WILSON, CHRISTOPHER
# 376320                                        Group, Danis
# 376314                                     ERNEST BLACKMAN
# 376327                           Olympia Development of MI
# 376385                                Pathways Development
# 376435                                 N & V Dionisopoulis
# 376370                                 N & V Dionisopoulos
# 376434                            MCCCARY EDWARDS, NATASHA
# 376459                              RAYAN GAS AND FOOD INC
# 376478                              RAYAN GAS AND FOOD INC
# 376473                                        Sami Siriani
# 376484                                 NOB Real Estate LLC
# 376482     NPML Mortgage Acquistion LLC c/o Home Servicing
# 376480     NPML Mortgage Acquistion LLC c/o Home Servicing
# 376479     NPML Mortgage Acquistion LLC c/o Home Servicing
# 376481     NPML Mortgage Acquistion LLC c/o Home Servicing
# 376483     NPML Mortgage Acquistion LLC c/o Home Servicing
# 376496                                       THE AIC GROUP
# 376497                                       THE AIC GROUP
# 376499                               BARLOW, CHRISTOPHER D
# 376500                                     WILLIAMS, JASON
# 369851                          LEONARD , KENNETH AND JEAN
#
#            violation_street_number violation_street_name violation_zip_code  \
# ticket_id
# 284932                     10041.0             ROSEBERRY                NaN
# 285362                     18520.0             EVERGREEN                NaN
# 285361                     18520.0             EVERGREEN                NaN
# 285338                      1835.0               CENTRAL                NaN
# 285346                      1700.0               CENTRAL                NaN
# 285345                      1700.0               CENTRAL                NaN
# 285347                      1700.0               CENTRAL                NaN
# 285342                      1605.0             LIVERNOIS                NaN
# 285530                      3408.0              BEATRICE                NaN
# 284989                      8040.0                SARENA                NaN
# 285344                      1733.0             LIVERNOIS                NaN
# 285343                      1733.0             LIVERNOIS                NaN
# 285340                      1671.0                 EVANS                NaN
# 285341                      1671.0                 EVANS                NaN
# 285349                      1649.0                 EVANS                NaN
# 285348                      1649.0                 EVANS                NaN
# 284991                      8014.0                SARENA                NaN
# 285532                      3027.0               BASSETT                NaN
# 285406                     15372.0                  WARD                NaN
# 285001                      1748.0               23RD ST                NaN
# 285006                      1748.0               23RD ST                NaN
# 285405                     18985.0               TRINITY                NaN
# 285337                     19968.0             GREENVIEW                NaN
# 285496                        79.0            LONGFELLOW                NaN
# 285497                        79.0            LONGFELLOW                NaN
# 285378                     19379.0           GLASTONBURY                NaN
# 285589                     18900.0             RIVERVIEW                NaN
# 285585                     17121.0               TRINITY                NaN
# 285501                       886.0              ATKINSON                NaN
# 285581                     19700.0              STAHELIN                NaN
# ...                            ...                   ...                ...
# 376367                      8230.0               FENKELL                NaN
# 376366                      8230.0               FENKELL                NaN
# 376362                     19010.0          WOODWARD AVE                NaN
# 376363                     19010.0          WOODWARD AVE                NaN
# 376365                      8230.0               FENKELL                NaN
# 376364                      8230.0               FENKELL                NaN
# 376228                      2457.0               RUSSELL              48207
# 376265                     15120.0                AUBURN                NaN
# 376286                     18297.0            WOODINGHAM              48224
# 376320                      5841.0                SECOND              48202
# 376314                     14316.0             JEFFERSON                NaN
# 376327                       150.0                BAGLEY                NaN
# 376385                      5565.0            KENSINGTON                NaN
# 376435                       527.0                MONROE              48206
# 376370                       527.0                MONROE              48226
# 376434                     18718.0                CARRIE              48234
# 376459                      3561.0            MT ELLIOTT              48207
# 376478                      3561.0            MT ELLIOTT              48207
# 376473                      8437.0                  MACK                NaN
# 376484                      4150.0           GRAND RIVER                NaN
# 376482                     18827.0               KLINGER                NaN
# 376480                     18827.0               KLINGER                NaN
# 376479                     18827.0               KLINGER                NaN
# 376481                     18827.0               KLINGER                NaN
# 376483                     18827.0               KLINGER                NaN
# 376496                     12032.0            SANTA ROSA              48204
# 376497                     12032.0            SANTA ROSA              48204
# 376499                     11832.0             KILBOURNE              48213
# 376500                     11848.0             KILBOURNE              48213
# 369851                      6100.0              IRONWOOD              48210
#
#           mailing_address_str_number mailing_address_str_name  \
# ticket_id
# 284932                           141                ROSEBERRY
# 285362                         19136              GLASTONBURY
# 285361                         19136              GLASTONBURY
# 285338                          2246                   NELSON
# 285346                          3435                   MUNGER
# 285345                          3435                   MUNGER
# 285347                          3435                   MUNGER
# 285342                          1382            WHITEHOUSE CT
# 285530                           341                  HAMPTON
# 284989                         43494           ELLSWORTH # 20
# 285344                           453              CLAYMORE DR
# 285343                           453              CLAYMORE DR
# 285340                           922                 P.O. BOX
# 285341                           922                 P.O. BOX
# 285349                          8214      WESTCHESTER STE 635
# 285348                          8214      WESTCHESTER STE 635
# 284991                           189                WOODCREST
# 285532                           327                  BASSETT
# 285406                          9251              LITTLEFIELD
# 285001                          1257                   Torrey
# 285006                          1257                   Torrey
# 285405                         19541              LEADWELL ST
# 285337                           264                 P.O. BOX
# 285496                          1828      COUNTRY CLUB CIRCLE
# 285497                          1828      COUNTRY CLUB CIRCLE
# 285378                            43            STEVENS CREEK
# 285589                         12166               REDWOOD RD
# 285585                         18248                  MARLOWE
# 285501                           886                 ATKINSON
# 285581                         14851                   TULLER
# ...                              ...                      ...
# 376367                           163             W. McNichols
# 376366                           163             W. McNichols
# 376362                           231                  Kenosha
# 376363                           231                  Kenosha
# 376365                          1916                Livernois
# 376364                          1916                Livernois
# 376228                          2457                  Russell
# 376265                            PO                BOX  1006
# 376286                          2385                EDINBURGH
# 376320                         18255                Wildemere
# 376314                           473                 CHALMERS
# 376327                          2211    Woodward Ave Bldg 102
# 376385                             1               Riverplace
# 376435                           525                   Monroe
# 376370                           525                   Monroe
# 376434                         17736                   BARLOW
# 376459                          3561            MT.ELLIOTT ST
# 376478                          3561            MT.ELLIOTT ST
# 376473                          3538               Byrd Drive
# 376484                         19853              Outer Drive
# 376482                           533         Highlandia Drive
# 376480                           533         Highlandia Drive
# 376479                           533         Highlandia Drive
# 376481                           533         Highlandia Drive
# 376483                           533         Highlandia Drive
# 376496                       P.O. BO                      969
# 376497                       P.O. BO                      969
# 376499                         11832                KILBOURNE
# 376500                          4317                YORKSHIRE
# 369851                            71                    TYLER
#
#                        city state      ...                        disposition  \
# ticket_id                              ...
# 284932              DETROIT    MI      ...             Responsible by Default
# 285362              DETROIT    MI      ...             Responsible by Default
# 285361              DETROIT    MI      ...             Responsible by Default
# 285338            WOODHAVEN    MI      ...             Responsible by Default
# 285346              LIVONIA    MI      ...             Responsible by Default
# 285345              LIVONIA    MI      ...             Responsible by Default
# 285347              LIVONIA    MI      ...             Responsible by Default
# 285342      ROCHESTER HILLS    MI      ...       Responsible by Determination
# 285530              GILBERT    SC      ...             Responsible by Default
# 284989              FREMONT    CA      ...             Responsible by Default
# 285344               CANTON    MI      ...             Responsible by Default
# 285343               CANTON    MI      ...             Responsible by Default
# 285340              DETROIT    MI      ...             Responsible by Default
# 285341              DETROIT    MI      ...             Responsible by Default
# 285349               DALLAS    TX      ...             Responsible by Default
# 285348               DALLAS    TX      ...             Responsible by Default
# 284991            HAZELWOOD    MO      ...             Responsible by Default
# 285532              DETROIT    MI      ...             Responsible by Default
# 285406              DETROIT    MI      ...             Responsible by Default
# 285001        Grosse Pointe    MI      ...             Responsible by Default
# 285006        Grosse Pointe    MI      ...             Responsible by Default
# 285405               RESEDA    CA      ...             Responsible by Default
# 285337              GILBERT    SC      ...             Responsible by Default
# 285496            RIVERVIEW    MI      ...             Responsible by Default
# 285497            RIVERVIEW    MI      ...             Responsible by Default
# 285378             SAN JOSE    CA      ...             Responsible by Default
# 285589             RIVERTON    UT      ...             Responsible by Default
# 285585              DETROIT    MI      ...             Responsible by Default
# 285501              DETROIT    MI      ...             Responsible by Default
# 285581              DETROIT    MI      ...             Responsible by Default
# ...                     ...   ...      ...                                ...
# 376367              DETROIT    MI      ...             Responsible by Default
# 376366              DETROIT    MI      ...             Responsible by Default
# 376362             Oak Park    MI      ...       Responsible by Determination
# 376363             Oak Park    MI      ...       Responsible by Determination
# 376365              DETROIT    MI      ...             Responsible by Default
# 376364              DETROIT    MI      ...             Responsible by Default
# 376228              Detroit    MI      ...             Responsible by Default
# 376265           BELLEVILLE    MI      ...             Responsible by Default
# 376286           SOUTHFIELD    MI      ...           Responsible by Admission
# 376320              Detroit    MI      ...             Responsible by Default
# 376314              DETROIT    MI      ...             Responsible by Default
# 376327              Detroit    MI      ...           Responsible by Admission
# 376385              Detroit    MI      ...           Responsible by Admission
# 376435              Detroit    MI      ...       Responsible by Determination
# 376370              Detroit    MI      ...       Responsible by Determination
# 376434              DETROIT    MI      ...             Responsible by Default
# 376459              DETROIT    MI      ...             Responsible by Default
# 376478              DETROIT    MI      ...             Responsible by Default
# 376473     Sterling Heights    MI      ...             Responsible by Default
# 376484             Dearborn    MI      ...             Responsible by Default
# 376482          Baton Rouge    LA      ...             Responsible by Default
# 376480          Baton Rouge    LA      ...             Responsible by Default
# 376479          Baton Rouge    LA      ...             Responsible by Default
# 376481          Baton Rouge    LA      ...             Responsible by Default
# 376483          Baton Rouge    LA      ...             Responsible by Default
# 376496           Southfield    MI      ...             Responsible by Default
# 376497           Southfield    MI      ...             Responsible by Default
# 376499              DETROIT    MI      ...             Responsible by Default
# 376500              DETROIT    MI      ...             Responsible by Default
# 369851              DETROIT    MI      ...             Responsible by Default
#
#            fine_amount admin_fee state_fee late_fee discount_amount  \
# ticket_id
# 284932           200.0      20.0      10.0     20.0             0.0
# 285362          1000.0      20.0      10.0    100.0             0.0
# 285361           100.0      20.0      10.0     10.0             0.0
# 285338           200.0      20.0      10.0     20.0             0.0
# 285346           100.0      20.0      10.0     10.0             0.0
# 285345           200.0      20.0      10.0     20.0             0.0
# 285347            50.0      20.0      10.0      5.0             0.0
# 285342           200.0      20.0      10.0      0.0             0.0
# 285530          1000.0      20.0      10.0    100.0             0.0
# 284989           500.0      20.0      10.0     50.0             0.0
# 285344            50.0      20.0      10.0      5.0             0.0
# 285343          1000.0      20.0      10.0    100.0             0.0
# 285340          1000.0      20.0      10.0    100.0             0.0
# 285341            50.0      20.0      10.0      5.0             0.0
# 285349           100.0      20.0      10.0     10.0             0.0
# 285348           200.0      20.0      10.0     20.0             0.0
# 284991           500.0      20.0      10.0     50.0             0.0
# 285532           500.0      20.0      10.0     50.0             0.0
# 285406           500.0      20.0      10.0     50.0             0.0
# 285001           500.0      20.0      10.0     50.0             0.0
# 285006          1000.0      20.0      10.0    100.0             0.0
# 285405          1000.0      20.0      10.0    100.0             0.0
# 285337           500.0      20.0      10.0     50.0             0.0
# 285496            50.0      20.0      10.0      5.0             0.0
# 285497           200.0      20.0      10.0     20.0             0.0
# 285378          1000.0      20.0      10.0    100.0             0.0
# 285589           500.0      20.0      10.0     50.0             0.0
# 285585           200.0      20.0      10.0     20.0             0.0
# 285501           100.0      20.0      10.0     10.0             0.0
# 285581          1000.0      20.0      10.0    100.0             0.0
# ...                ...       ...       ...      ...             ...
# 376367           750.0      20.0      10.0     75.0             0.0
# 376366           250.0      20.0      10.0     25.0             0.0
# 376362           250.0      20.0      10.0     25.0             0.0
# 376363           200.0      20.0      10.0     20.0             0.0
# 376365           750.0      20.0      10.0     75.0             0.0
# 376364           250.0      20.0      10.0     25.0             0.0
# 376228           250.0      20.0      10.0     25.0             0.0
# 376265           250.0      20.0      10.0     25.0             0.0
# 376286           250.0      20.0      10.0      0.0             0.0
# 376320           250.0      20.0      10.0     25.0             0.0
# 376314           250.0      20.0      10.0     25.0             0.0
# 376327           250.0      20.0      10.0      0.0             0.0
# 376385           250.0      20.0      10.0      0.0             0.0
# 376435           750.0      20.0      10.0      0.0             0.0
# 376370           250.0      20.0      10.0      0.0             0.0
# 376434            50.0      20.0      10.0      5.0             0.0
# 376459           100.0      20.0      10.0     10.0             0.0
# 376478          5000.0      20.0      10.0    500.0             0.0
# 376473           250.0      20.0      10.0     25.0             0.0
# 376484           300.0      20.0      10.0     30.0             0.0
# 376482           500.0      20.0      10.0     50.0             0.0
# 376480           500.0      20.0      10.0     50.0             0.0
# 376479           500.0      20.0      10.0     50.0             0.0
# 376481           500.0      20.0      10.0     50.0             0.0
# 376483           250.0      20.0      10.0     25.0             0.0
# 376496          1000.0      20.0      10.0    100.0             0.0
# 376497          1000.0      20.0      10.0    100.0             0.0
# 376499           100.0      20.0      10.0     10.0             0.0
# 376500           100.0      20.0      10.0     10.0             0.0
# 369851            50.0      20.0      10.0      0.0             0.0
#
#           clean_up_cost judgment_amount  grafitti_status    compliance
# ticket_id
# 284932              0.0           250.0              NaN  5.979014e-02
# 285362              0.0          1130.0              NaN  5.796201e-03
# 285361              0.0           140.0              NaN  7.895886e-02
# 285338              0.0           250.0              NaN  5.979014e-02
# 285346              0.0           140.0              NaN  7.895886e-02
# 285345              0.0           250.0              NaN  5.979014e-02
# 285347              0.0            85.0              NaN  9.052550e-02
# 285342              0.0           230.0              NaN  1.791831e-01
# 285530              0.0          1130.0              NaN  5.796201e-03
# 284989              0.0           580.0              NaN  2.530022e-02
# 285344              0.0            85.0              NaN  9.052550e-02
# 285343              0.0          1130.0              NaN  5.796201e-03
# 285340              0.0          1130.0              NaN  5.796201e-03
# 285341              0.0            85.0              NaN  9.052550e-02
# 285349              0.0           140.0              NaN  7.895886e-02
# 285348              0.0           250.0              NaN  5.979014e-02
# 284991              0.0           580.0              NaN  2.530022e-02
# 285532              0.0           580.0              NaN  2.530022e-02
# 285406              0.0           580.0              NaN  2.530022e-02
# 285001              0.0           580.0              NaN  2.530022e-02
# 285006              0.0          1130.0              NaN  5.796201e-03
# 285405              0.0          1130.0              NaN  5.796201e-03
# 285337              0.0           580.0              NaN  2.530022e-02
# 285496              0.0            85.0              NaN  9.052550e-02
# 285497              0.0           250.0              NaN  5.979014e-02
# 285378              0.0          1130.0              NaN  5.796201e-03
# 285589              0.0           580.0              NaN  2.530022e-02
# 285585              0.0           250.0              NaN  5.979014e-02
# 285501              0.0           140.0              NaN  7.895886e-02
# 285581              0.0          1130.0              NaN  5.796201e-03
# ...                 ...             ...              ...           ...
# 376367              0.0           855.0              NaN  1.215209e-02
# 376366              0.0           305.0              NaN  5.192640e-02
# 376362              0.0           305.0              NaN  5.192640e-02
# 376363              0.0           250.0              NaN  5.979014e-02
# 376365              0.0           855.0              NaN  1.215209e-02
# 376364              0.0           305.0              NaN  5.192640e-02
# 376228              0.0           305.0              NaN  5.192640e-02
# 376265              0.0           305.0              NaN  5.192640e-02
# 376286              0.0           280.0              NaN  2.037708e-01
# 376320              0.0           305.0              NaN  5.192640e-02
# 376314              0.0           305.0              NaN  5.192640e-02
# 376327              0.0           280.0              NaN  2.037708e-01
# 376385              0.0           280.0              NaN  2.037708e-01
# 376435              0.0           780.0              NaN  5.565351e-01
# 376370              0.0           280.0              NaN  2.037708e-01
# 376434              0.0            85.0              NaN  9.052550e-02
# 376459              0.0           140.0  GRAFFITI TICKET  7.895886e-02
# 376478              0.0          5530.0              NaN  3.775586e-08
# 376473              0.0           305.0              NaN  5.192640e-02
# 376484              0.0           360.0              NaN  4.504737e-02
# 376482              0.0           580.0              NaN  2.530022e-02
# 376480              0.0           580.0              NaN  2.530022e-02
# 376479              0.0           580.0              NaN  2.530022e-02
# 376481              0.0           580.0              NaN  2.530022e-02
# 376483              0.0           305.0              NaN  5.192640e-02
# 376496              0.0          1130.0              NaN  5.796201e-03
# 376497              0.0          1130.0              NaN  5.796201e-03
# 376499              0.0           140.0              NaN  7.895886e-02
# 376500              0.0           140.0              NaN  7.895886e-02
# 369851              0.0            80.0              NaN  1.193192e-01
#
# [61001 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data)

clf = LogisticRegression(C=0.0001).fit(X_train, y_train)
print(clf.score(X_test, y_test))
y_proba_clf = clf.predict_proba(X_test)
print(roc_auc_score(y_test,clf.predict_proba(X_test)[:,1],))



y_score_clf = clf.decision_function(X_test)
fpr_clf, tpr_clf, _ = roc_curve(y_test, y_score_clf)
roc_auc_clf = auc(fpr_clf, tpr_clf)

plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr_clf, tpr_clf, lw=3, label='LogRegr ROC curve (area = {:0.2f})'.format(roc_auc_clf))
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc='lower right', fontsize=13)
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
#plt.axes().set_aspect('equal')
plt.show()
# Out:
# 0.9313735301476107
# 0.7567212124307516

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
clf =RandomForestClassifier(n_estimators=100,max_depth=8,n_jobs=-1,random_state=0)
X_train,X_valid,y_train,y_valid = train_test_split(X_data,y_data,test_size= 0.2,)
clf.fit(X_train, y_train)
roc_auc_score(y_valid,clf.predict_proba(X_valid)[:,1],)
y_pred = clf.predict_proba(test[features])[:,1]
y_pred
# Out:
# array([0.06052211, 0.02665536, 0.06947023, ..., 0.06947023, 0.06947023,
#        0.26394754])

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data)


'''
clf = SVC(kernel='rbf')
grid_values = {'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100]}
#grid_values = {'gamma': [0.001,1]}

# default metric to optimize over grid parameters: accuracy
grid_clf = GridSearchCV(clf, param_grid = grid_values)
grid_clf.fit(X_train, y_train)
y_decision_scoresc = grid_clf.decision_function(X_test) 

print('Test set AUC: ', roc_auc_score(y_test, y_decision_scoresc))
print('Grid best parameter (max. AUC): ', grid_clf.best_params_)
print('Grid best score (AUC): ', grid_clf.best_score_)
'''

clf = LogisticRegression()
grid_values = {'C': [0.0001, 0.001, 0.01, 0.05, 0.1, 1, 10, 100]}
# default metric to optimize over grid parameters: accuracy
grid_clf = GridSearchCV(clf, param_grid = grid_values)
grid_clf.fit(X_train, y_train)
y_decision_scoresc = grid_clf.decision_function(X_test) 

print('Test set AUC: ', roc_auc_score(y_test, y_decision_scoresc))
print('Grid best parameter (max. AUC): ', grid_clf.best_params_)
print('Grid best score (AUC): ', grid_clf.best_score_)



'''
y_score_clf = clf.decision_function(X_test)
fpr_clf, tpr_clf, _ = roc_curve(y_test, y_score_clf)
roc_auc_clf = auc(fpr_clf, tpr_clf)

plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr_clf, tpr_clf, lw=3, label='LogRegr ROC curve (area = {:0.2f})'.format(roc_auc_clf))
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc='lower right', fontsize=13)
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
#plt.axes().set_aspect('equal')
plt.show()
'''
# Out:
# Test set AUC:  0.7552919311941722
# Grid best parameter (max. AUC):  {'C': 0.001}
# Grid best score (AUC):  0.9344925360687182
# "\ny_score_clf = clf.decision_function(X_test)\nfpr_clf, tpr_clf, _ = roc_curve(y_test, y_score_clf)\nroc_auc_clf = auc(fpr_clf, tpr_clf)\n\nplt.figure()\nplt.xlim([-0.01, 1.00])\nplt.ylim([-0.01, 1.01])\nplt.plot(fpr_clf, tpr_clf, lw=3, label='LogRegr ROC curve (area = {:0.2f})'.format(roc_auc_clf))\nplt.xlabel('False Positive Rate', fontsize=16)\nplt.ylabel('True Positive Rate', fontsize=16)\nplt.title('ROC curve', fontsize=16)\nplt.legend(loc='lower right', fontsize=13)\nplt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')\n#plt.axes().set_aspect('equal')\nplt.show()\n"

# %%
from collections import Counter
Counter(df1['violation_code'])
# Out:
# Counter({'9-1-36(a)': 99091,
#          '61-63.0600': 77,
#          '61-63.0500': 18,
#          '61-63.0100': 153,
#          '9-1-103(C)': 3537,
#          '22-2-83(a)(b)(c)': 849,
#          '22-2-21(b)': 286,
#          '9-1-36(c)': 29,
#          '22-2-17': 1940,
#          '22-2-49': 10,
#          '22-2-23': 46,
#          '61-47.0000/47.0108': 2,
#          '61-90.0100': 9,
#          '22-2-88': 28720,
#          '19450901': 2963,
#          '22-2-43': 2903,
#          '9-1-355': 60,
#          '22-2-56': 112,
#          '22-2-83': 633,
#          '22-2-22': 3755,
#          '22-2-45': 5394,
#          '9-1-110(a)': 4814,
#          '22-2-88(a)': 342,
#          '61-116.0100/32.0031': 1,
#          '22-2-83a': 11,
#          '9-1-105': 5072,
#          '22-2-16': 80,
#          '9-1-104': 22536,
#          '9-1-353(2)': 2,
#          '20130901': 175,
#          '9-1-101': 294,
#          '22-2-61': 1456,
#          '9-1-201(a)': 178,
#          '9-1-209': 335,
#          '61-130.0000/130.0400': 4,
#          '22-2-41': 102,
#          '9-1-43(a) - (Dwellin': 5332,
#          '9-1-205': 182,
#          '9-1-107': 222,
#          '9-1-206': 344,
#          '9-1-201(b)': 110,
#          '9-1-210': 38,
#          '9-1-220': 4,
#          '9-1-214': 10,
#          '9-1-103 (a) or (b)': 54,
#          '9-1-477': 27,
#          '9-1-211': 11,
#          '9-1-204': 9,
#          '9-1-310': 5,
#          '9-1-208': 41,
#          '61-81.0100/32.0066': 812,
#          '9-1-81(a)': 43471,
#          '9-1-476': 22,
#          '22-2-44': 78,
#          '9-1-303': 59,
#          '61-130.0000/130.0300': 1,
#          '9-1-111': 201,
#          '9-1-110(b)': 28,
#          '9-1-221': 5,
#          '9-1-36(d)': 8,
#          '22-2-20': 5,
#          '22-2-87(a)': 4,
#          '61-80.0100': 17,
#          '9-1-106': 2,
#          '9-1-108': 6,
#          '9-1-43(a) - (Structu': 765,
#          '19830901': 33,
#          '61-82.0100/32.0066': 8,
#          '61-81.0100/45.0807': 3,
#          '61-83.0100/32.0066': 9,
#          '9-1-45(c)': 6,
#          '61-102.0100/32.0066': 5,
#          '61-101.0100/32.0066': 27,
#          '22-2-84(a)(1)(2)(4)': 71,
#          '9-1-503': 10,
#          '22-2-85': 4,
#          '22-2-86': 3,
#          '61-130.0000/130.0500': 2,
#          '9-1-216': 13,
#          '9-1-43(a) - (Stories': 457,
#          '22-2-91': 31,
#          '9-1-304': 21,
#          '9-1-102': 7,
#          '9-1-212': 46,
#          '22-2-38': 167,
#          '22-2-94': 4,
#          '22-2-84 (DO NOT USE ': 4,
#          '9-1-207': 9,
#          '9-1-354': 1,
#          '9-1-306': 12,
#          '61-111.0100/32.0066': 1,
#          '61-84.0100/32.0066': 17,
#          '9-1-213': 43,
#          '61-121.0100/32.0066': 3,
#          '61-120.0100/32.0066': 1,
#          '61-105.0100/32.066': 1,
#          '9-1-464': 8,
#          '9-1-441': 4,
#          '9-1-441(a)': 3,
#          '9-1-462(a)': 1,
#          '9-1-474': 3,
#          '9-1-432(a)': 10,
#          '22-2-55': 31,
#          '9-1-440': 4,
#          '22-2-87': 43,
#          '22-2-53': 36,
#          '9-1-81(b)': 16,
#          '9-1-301': 12,
#          '9-1-331': 10,
#          '9-1-202': 55,
#          '9-1-442': 11,
#          '9-1-351': 7,
#          '9-1-406': 1,
#          '22-2-97(b)': 39,
#          '9-1-311': 86,
#          '9-1-12(b)': 14,
#          '9-1-469': 13,
#          '9-1-478': 2,
#          '9-1-433': 1,
#          '9-1-439': 14,
#          '9-1-375': 1,
#          '9-1-307': 10,
#          '9-1-305': 8,
#          '9-1-444': 2,
#          '9-1-309': 12,
#          '9-1-465': 4,
#          '61-4-32': 96,
#          '9-1-501': 1,
#          '61-4-33': 115,
#          '9-1-443(a)': 5,
#          '9-1-479': 2,
#          '9-1-443(b)': 1,
#          '22-2-18': 5,
#          '61-114.0100/32.0031': 1,
#          '9-1-45(b)': 24,
#          '9-1-46(a)': 2,
#          '9-1-468': 6,
#          '9-1-405': 3,
#          '9-1-219': 1,
#          '22-2-42': 4,
#          '20180901': 22,
#          '61-114.0100': 2,
#          '22-2-96': 12,
#          '61-5-21': 426,
#          '19840901': 3,
#          '9-1-377': 1,
#          '9-1-81(e)': 7,
#          '9-1-471': 1,
#          '19850901': 13,
#          '61-4-38': 1,
#          '61-8-127': 27,
#          '61-8-27': 124,
#          '22-2-93': 70,
#          '9-1-109': 13,
#          '9-1-333': 3,
#          '9-1-112': 13,
#          '61-5-19': 62,
#          '61-81.0100/32.0031': 3,
#          '61-83.0100/32.0031': 4,
#          '22-3-2': 68,
#          '61-8-47': 23,
#          '61-45.0000': 1,
#          '9-1-352': 1,
#          '9-1-203': 19,
#          '61-5-18': 273,
#          '61-122.0100/32.0066': 1,
#          '9-1-302': 2,
#          '22-2-21(a)': 5,
#          '61-118.0100/32.0066': 1,
#          '22-2-84(b)(3)': 36,
#          '19420901': 68,
#          '22-2-25': 3,
#          '61-14-176': 2,
#          '61-86.0100/32.0076B': 2,
#          '61-86.0100/32.0066': 3,
#          '61-85.0100/32.0066': 2,
#          '61-82.0100/32.0031': 2,
#          '61-104.0100': 1,
#          '9-1-215': 1,
#          '61-5-20': 4,
#          '61-86.0100/32.0031': 2,
#          '61-86.0100/45.0807': 1,
#          '61-45.0000/45.0800': 1,
#          '61-14-175': 3,
#          '9-1-381': 1,
#          '61-115.0100/32.0031': 2,
#          '61-85.0100/32.0031': 2,
#          '61-4-35': 2,
#          '61-84.0100/45.0807': 2,
#          '61-85.0100/45.0807': 4,
#          '61-4-37': 91,
#          '61-100.0100': 3,
#          '9-1-502': 1,
#          '9-1-82(d) - (Dwellin': 895,
#          '22-2-88(b)': 7238,
#          '22-2-22(a)': 143,
#          '22-2-17(a)': 182,
#          '22-2-83(c)': 126,
#          '22-2-83(b)': 38,
#          '22-2-83(d)': 17,
#          '22-2-84(a)': 24,
#          '22-2-84(b)(1)': 7,
#          '22-2-49(a)': 2,
#          '22-2-49(c)': 4,
#          '61-14-452(2)': 1,
#          '9-1-82(d) - (Structu': 57,
#          '22-2-92': 7,
#          '9-1-83 - (Dwelling)': 145,
#          '61-96.0100/32.0066': 1,
#          '22-2-19': 2,
#          '61-116.0100/32.0076B': 1,
#          '22-2-97': 1,
#          '22-2-42(b)': 2,
#          '9-1-83 - (Structures': 23,
#          '9-1-82(b)': 61,
#          '9-1-82(d) - (Buildin': 15,
#          '9-1-466': 2,
#          '9-1-434': 1,
#          '9-1-83 - (Building 5': 7,
#          '9-1-332': 1,
#          '9-1-308': 1,
#          '22-2-49(d)': 6,
#          '22-2-96(a)': 2,
#          '22-2-41(b)': 2,
#          '22-3-3': 1,
#          '9-1-50 (e)': 70,
#          '61-84.0100/32.0031': 1,
#          '9-1-113': 81,
#          '9-1-50(b)': 12,
#          '22-2-49(b)': 5,
#          '20160901': 1,
#          '9-1-50(a)': 70,
#          '61-84.0100/32.0076B': 1,
#          '61-105.0100/32.0076B': 1,
#          '19410901': 1})

# %%
import pandas as pd
import numpy as np

def blight_model():
    
    # Your code here
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import roc_auc_score
    
    train_data = pd.read_csv('./train.csv',encoding = 'ISO-8859-1' )
    train_data = train_data[pd.notnull(train_data.compliance)]
    test_data = pd.read_csv('./test.csv',encoding='ISO-8859-1')
    test_data.set_index('ticket_id',inplace=True)
    
    COL = test_data.columns.tolist()
    target = ['compliance']
    
    features = [ 'fine_amount',
     'admin_fee',
     'state_fee',
     'late_fee',
     'discount_amount',
    # 'clean_up_cost',
     'judgment_amount',]
    clf =RandomForestClassifier(n_estimators=100,max_depth=8,n_jobs=-1,random_state=0)
    X_train,X_valid,y_train,y_valid = train_test_split(train_data[features],train_data[target],test_size= 0.2,)
    clf.fit(train_data[features],train_data[target])
    #roc_auc_score(y_valid,clf.predict_proba(X_valid)[:,1],)
    y_pred = clf.predict_proba(test_data[features])[:,1]
    test_data['compliance'] = y_pred
    
    return test_data['compliance']# Your answer here

# %%
blight_model()
# Out:
# D:\Users\iamfish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2909: DtypeWarning: Columns (11,12,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# D:\Users\iamfish\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ticket_id
# 284932    0.060670
# 285362    0.023607
# 285361    0.069818
# 285338    0.060670
# 285346    0.069818
# 285345    0.060670
# 285347    0.057241
# 285342    0.378009
# 285530    0.023607
# 284989    0.031364
# 285344    0.057241
# 285343    0.023607
# 285340    0.023607
# 285341    0.057241
# 285349    0.069818
# 285348    0.060670
# 284991    0.031364
# 285532    0.031364
# 285406    0.031364
# 285001    0.031364
# 285006    0.023607
# 285405    0.023607
# 285337    0.031364
# 285496    0.057241
# 285497    0.060670
# 285378    0.023607
# 285589    0.031364
# 285585    0.060670
# 285501    0.069818
# 285581    0.023607
#             ...
# 376367    0.032830
# 376366    0.036070
# 376362    0.036070
# 376363    0.060670
# 376365    0.032830
# 376364    0.036070
# 376228    0.036070
# 376265    0.036070
# 376286    0.305319
# 376320    0.036070
# 376314    0.036070
# 376327    0.305319
# 376385    0.305319
# 376435    0.442918
# 376370    0.305319
# 376434    0.057241
# 376459    0.069818
# 376478    0.000100
# 376473    0.036070
# 376484    0.018295
# 376482    0.031364
# 376480    0.031364
# 376479    0.031364
# 376481    0.031364
# 376483    0.036070
# 376496    0.023607
# 376497    0.023607
# 376499    0.069818
# 376500    0.069818
# 369851    0.262206
# Name: compliance, Length: 61001, dtype: float64
