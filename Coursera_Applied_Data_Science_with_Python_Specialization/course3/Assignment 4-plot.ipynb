# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

train = pd.read_csv('train.csv', encoding='latin1')
test  = pd.read_csv('test.csv')
addr  = pd.read_csv('addresses.csv')
latlon= pd.read_csv('latlons.csv')

df1 = train.merge(addr, left_on='ticket_id', right_on='ticket_id', how='left')
df1 = df1.merge(latlon, left_on='address', right_on='address', how='left')
df1b = df1[['ticket_id', 'lat', 'lon', 'compliance']].dropna()
X_data = df1b[['lat', 'lon']]
y_data = df1b['compliance']
# Out:
# D:\Users\iamfish\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11,12,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
plt.figure(figsize=(12, 12), dpi=200)
plt.scatter(df1b[df1b.compliance==0].lat, df1b[df1b.compliance==0].lon, c='r', alpha=0.5, s=0.5)
plt.scatter(df1b[df1b.compliance==1].lat, df1b[df1b.compliance==1].lon, c='g', alpha=0.5, s=0.5)

plt.xlim([42.2, 42.5])
plt.ylim([-82.8, -83.4])

plt.show()

# %%
df1[df1.compliance==1].judgment_amount
# Out:
# 1         855.0
# 18        140.0
# 19        140.0
# 37        305.0
# 41        280.0
# 44        280.0
# 59        305.0
# 60        140.0
# 61        140.0
# 77        250.0
# 88        280.0
# 89        305.0
# 112       855.0
# 117       140.0
# 120       305.0
# 126       130.0
# 127       130.0
# 138       305.0
# 168       305.0
# 170       280.0
# 172       140.0
# 175       305.0
# 178       280.0
# 202       305.0
# 204       305.0
# 212        57.5
# 213       305.0
# 214       305.0
# 215       305.0
# 218       305.0
#           ...
# 249942    230.0
# 249943    155.0
# 249945    250.0
# 249946    250.0
# 249947     85.0
# 249953    230.0
# 249967    230.0
# 249977     80.0
# 249981    230.0
# 249994    230.0
# 250000     85.0
# 250004    305.0
# 250021     80.0
# 250041      0.0
# 250049    250.0
# 250062    230.0
# 250090    250.0
# 250101    230.0
# 250111    250.0
# 250119    230.0
# 250134    230.0
# 250141    230.0
# 250142    250.0
# 250161    250.0
# ...

# %%
df1[df1.compliance==0].judgment_amount
# Out:
# 0          305.0
# 5          305.0
# 6          855.0
# 7          140.0
# 8          140.0
# 9          855.0
# 12         855.0
# 13         855.0
# 14         855.0
# 21         855.0
# 22         855.0
# 23         855.0
# 26         130.0
# 28         305.0
# 30         305.0
# 31         305.0
# 33         305.0
# 34         305.0
# 35         305.0
# 38         305.0
# 39         305.0
# 40         305.0
# 42         280.0
# 43         305.0
# 46         280.0
# 47         305.0
# 48         305.0
# 52         280.0
# 53        3880.0
# 56         305.0
#            ...
# 250232     280.0
# 250243     305.0
# 250244     855.0
# 250249     305.0
# 250250     280.0
# 250254     580.0
# 250255     305.0
# 250256     305.0
# 250257    1130.0
# 250258    1130.0
# 250259    1130.0
# 250261     140.0
# 250262     140.0
# 250264      85.0
# 250266      85.0
# 250267      85.0
# 250268      85.0
# 250269      85.0
# 250270      85.0
# 250271      85.0
# 250272      85.0
# ...

# %%
(df1[df1.compliance==0].judgment_amount > df1[df1.compliance==0].judgment_amount.mean())
# Out:
# 0         False
# 5         False
# 6          True
# 7         False
# 8         False
# 9          True
# 12         True
# 13         True
# 14         True
# 21         True
# 22         True
# 23         True
# 26        False
# 28        False
# 30        False
# 31        False
# 33        False
# 34        False
# 35        False
# 38        False
# 39        False
# 40        False
# 42        False
# 43        False
# 46        False
# 47        False
# 48        False
# 52        False
# 53         True
# 56        False
#           ...
# 250232    False
# 250243    False
# 250244     True
# 250249    False
# 250250    False
# 250254     True
# 250255    False
# 250256    False
# 250257     True
# 250258     True
# 250259     True
# 250261    False
# 250262    False
# 250264    False
# 250266    False
# 250267    False
# 250268    False
# 250269    False
# 250270    False
# 250271    False
# 250272    False
# 250273    False
# 250274     True
# 250275    False
# ...
